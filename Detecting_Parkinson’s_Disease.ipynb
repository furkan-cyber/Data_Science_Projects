# %%
import pandas as pd

# %%
parkinson_df=pd.read_csv("parkinsons (1).data")

# %%
parkinson_df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
parkinson_df.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %%
parkinson_df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
parkinson_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
parkinson_df["status"].value_counts() #1:people is parkinson 0:people is not parkinson
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
import seaborn as sns

sns.countplot(x="status",data=parkinson_df);#1:people is parkinson 0:people is not parkinson

# %%
parkinson_df.corr()["status"] # is not a strong correlations for status
# Out:
# MDVP:Fo(Hz)        -0.383535
# MDVP:Fhi(Hz)       -0.166136
# MDVP:Flo(Hz)       -0.380200
# MDVP:Jitter(%)      0.278220
# MDVP:Jitter(Abs)    0.338653
# MDVP:RAP            0.266668
# MDVP:PPQ            0.288698
# Jitter:DDP          0.266646
# MDVP:Shimmer        0.367430
# MDVP:Shimmer(dB)    0.350697
# Shimmer:APQ3        0.347617
# Shimmer:APQ5        0.351148
# MDVP:APQ            0.364316
# Shimmer:DDA         0.347608
# NHR                 0.189429
# HNR                -0.361515
# status              1.000000
# RPDE                0.308567
# DFA                 0.231739
# spread1             0.564838
# spread2             0.454842
# D2                  0.340232
# PPE                 0.531039
# Name: status, dtype: float64

# %%
columns=parkinson_df.columns
sns.boxplot(x=columns[1],data=parkinson_df) # clean
# Out:
# <AxesSubplot:xlabel='MDVP:Fo(Hz)'>

# %%
columns=parkinson_df.columns
sns.boxplot(x=columns[2],data=parkinson_df)
# Out:
# <AxesSubplot:xlabel='MDVP:Fhi(Hz)'>

# %%
columns=parkinson_df.columns
sns.boxplot(x=columns[3],data=parkinson_df)
# Out:
# <AxesSubplot:xlabel='MDVP:Flo(Hz)'>

# %%
columns=parkinson_df.columns
sns.boxplot(x=columns[4],data=parkinson_df)
# Out:
# <AxesSubplot:xlabel='MDVP:Jitter(%)'>

# %%
columns=parkinson_df.columns
sns.boxplot(x=columns[5],data=parkinson_df)
# Out:
# <AxesSubplot:xlabel='MDVP:Jitter(Abs)'>

# %%
# A lot of outlier values .We should clean that

# %%
parkinson_df.drop(["name"],axis=1,inplace=True)
label=parkinson_df.columns
for i in label:
    if i!="status":
      q1=parkinson_df[i].quantile(0.25)
      q3=parkinson_df[i].quantile(0.75)
      ıqr=q3-q1
      lower=q1-(1.5*ıqr)
      upper=q3+(1.5*ıqr)
      lower_radical=(parkinson_df[i]<(lower))
      upper_radical=(parkinson_df[i]>(upper))
      parkinson_df[i][lower_radical]=lower
      parkinson_df[i][upper_radical]=upper
print("Data Cleaned")
# Out:
# Data Cleaned
# <ipython-input-16-927c3b2f9c31>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parkinson_df[i][lower_radical]=lower
# <ipython-input-16-927c3b2f9c31>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parkinson_df[i][upper_radical]=upper
# <ipython-input-16-927c3b2f9c31>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parkinson_df[i][lower_radical]=lower
# ...

# %%
import numpy as np
def minmax(arr):
    l = np.min(arr)
    h = np.max(arr)
    return (arr -l) / (h-l)

# %%
df_2=parkinson_df.drop(["status"],axis=1)
minmax(df_2)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0       0.184308      0.215394      0.060209        0.533680
# 1       0.198327      0.181607      0.305710        0.693091
# 2       0.165039      0.113115      0.291393        0.764133
# 3       0.165004      0.139514      0.290197        0.718215
# 4       0.161150      0.154783      0.285701        0.966862
# ..           ...           ...           ...             ...
# 190     0.499820      0.503107      0.182029        0.252112
# 191     0.705488      0.589171      0.151846        0.343080
# 192     0.502730      0.538358      0.055719        1.000000
# 193     0.642893      1.000000      0.059620        0.495560
# 194     0.733274      0.617522      0.079028        0.345679
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0            0.557522  0.470588  0.747875    0.470252      0.566085
# 1            0.646018  0.618621  0.977742    0.618342      0.857403
# ...

# %%
df_2["status"]=parkinson_df["status"]

# %%
df_2
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997        0.007840
# 1        122.400       148.650       113.819        0.009680
# 2        116.682       131.111       111.555        0.010500
# 3        116.676       137.871       111.366        0.009970
# 4        116.014       141.781       110.655        0.012840
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261        0.004590
# 191      209.516       253.017        89.488        0.005640
# 192      174.688       240.005        74.287        0.013222
# 193      198.764       358.220        74.904        0.007400
# 194      214.289       260.277        77.973        0.005670
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370  0.005540     0.01109       0.04374
# 1             0.00008   0.00465  0.006960     0.01394       0.06134
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
from xgboost import XGBClassifier

# %%
Y=df_2[["status"]]
X=df_2.drop(["status"],axis=1)

# %%
X
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997        0.007840
# 1        122.400       148.650       113.819        0.009680
# 2        116.682       131.111       111.555        0.010500
# 3        116.676       137.871       111.366        0.009970
# 4        116.014       141.781       110.655        0.012840
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261        0.004590
# 191      209.516       253.017        89.488        0.005640
# 192      174.688       240.005        74.287        0.013222
# 193      198.764       358.220        74.904        0.007400
# 194      214.289       260.277        77.973        0.005670
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370  0.005540     0.01109       0.04374
# 1             0.00008   0.00465  0.006960     0.01394       0.06134
# ...

# %%
Y
# Out:
#      status
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 190       0
# 191       0
# 192       0
# 193       0
# 194       0
#
# [195 rows x 1 columns]

# %%
from imblearn.over_sampling import SMOTE
>>> X, Y = SMOTE().fit_resample(X, Y)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33)

# %%
xgb=XGBClassifier()

# %%
model=xgb.fit(X_train,Y_train)
# Out:
# C:\Users\fassf\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\fassf\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
y_pred=model.predict(X_test)

# %%
print(classification_report(Y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96        54
#            1       0.93      0.98      0.96        44
#
#     accuracy                           0.96        98
#    macro avg       0.96      0.96      0.96        98
# weighted avg       0.96      0.96      0.96        98

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10,10))
sns.barplot(y=X.columns, x=xgb.feature_importances_);
plt.xlabel("Feature Importance");
