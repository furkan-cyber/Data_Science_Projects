# %% [markdown]
# # DATA MANIPULATION

# %%
import pandas as pd

# %%
df=pd.read_csv("CarPrice_Assignment (1).csv")

# %%
df=df.copy()

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
str_list=df.select_dtypes(include="object").columns

# %%
str_list=list(str_list)

# %%
str_list
# Out:
# ['CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
for i in str_list:
    print(f"{i}: "+df[i].unique())
# Out:
# ['CarName: alfa-romero giulia' 'CarName: alfa-romero stelvio'
#  'CarName: alfa-romero Quadrifoglio' 'CarName: audi 100 ls'
#  'CarName: audi 100ls' 'CarName: audi fox' 'CarName: audi 5000'
#  'CarName: audi 4000' 'CarName: audi 5000s (diesel)' 'CarName: bmw 320i'
#  'CarName: bmw x1' 'CarName: bmw x3' 'CarName: bmw z4' 'CarName: bmw x4'
#  'CarName: bmw x5' 'CarName: chevrolet impala'
#  'CarName: chevrolet monte carlo' 'CarName: chevrolet vega 2300'
#  'CarName: dodge rampage' 'CarName: dodge challenger se'
#  'CarName: dodge d200' 'CarName: dodge monaco (sw)'
#  'CarName: dodge colt hardtop' 'CarName: dodge colt (sw)'
#  'CarName: dodge coronet custom' 'CarName: dodge dart custom'
#  'CarName: dodge coronet custom (sw)' 'CarName: honda civic'
#  'CarName: honda civic cvcc' 'CarName: honda accord cvcc'
#  'CarName: honda accord lx' 'CarName: honda civic 1500 gl'
#  'CarName: honda accord' 'CarName: honda civic 1300'
#  'CarName: honda prelude' 'CarName: honda civic (auto)'
# ...

# %%
df.describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# ...

# %%
df["fueltype"].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
df["aspiration"].value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
df["doornumber"].value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
df["enginelocation"].value_counts()
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
df["drivewheel"].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
df["fuelsystem"].value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
df["carbody"].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
df.groupby("fuelsystem")["fueltype"].value_counts()
# Out:
# fuelsystem  fueltype
# 1bbl        gas         11
# 2bbl        gas         66
# 4bbl        gas          3
# idi         diesel      20
# mfi         gas          1
# mpfi        gas         94
# spdi        gas          9
# spfi        gas          1
# Name: fueltype, dtype: int64

# %%
df.groupby("carbody")["enginelocation"].value_counts()
# Out:
# carbody      enginelocation
# convertible  front              5
#              rear               1
# hardtop      front              6
#              rear               2
# hatchback    front             70
# sedan        front             96
# wagon        front             25
# Name: enginelocation, dtype: int64

# %%
df.groupby("cylindernumber")["enginetype"].value_counts()
# Out:
# cylindernumber  enginetype
# eight           ohcv            4
#                 dohcv           1
# five            ohc            11
# four            ohc           130
#                 ohcf           12
#                 l              11
#                 dohc            6
# six             ohcv            8
#                 ohc             7
#                 dohc            6
#                 ohcf            3
# three           l               1
# twelve          ohcv            1
# two             rotor           4
# Name: enginetype, dtype: int64

# %%
df.groupby("fuelsystem")["enginetype"].value_counts()
# Out:
# fuelsystem  enginetype
# 1bbl        ohc           11
# 2bbl        ohc           57
#             ohcf           8
#             l              1
# 4bbl        rotor          3
# idi         ohc           15
#             l              5
# mfi         ohc            1
# mpfi        ohc           54
#             ohcv          13
#             dohc          12
#             ohcf           7
#             l              6
#             dohcv          1
#             rotor          1
# spdi        ohc            9
# spfi        ohc            1
# Name: enginetype, dtype: int64

# %%
df.groupby("fuelsystem")["doornumber"].value_counts()
# Out:
# fuelsystem  doornumber
# 1bbl        two            7
#             four           4
# 2bbl        four          38
#             two           28
# 4bbl        two            3
# idi         four          17
#             two            3
# mfi         two            1
# mpfi        four          54
#             two           40
# spdi        two            7
#             four           2
# spfi        two            1
# Name: doornumber, dtype: int64

# %%
df.price[df.price>35000].value_counts().sum()
# Out:
# 8

# %%
df.price[df.price<7500].value_counts().sum()
# Out:
# 44

# %%
df.price[(df.price<35000) & (df.price>7500)].value_counts().sum()
# Out:
# 153

# %%
df.horsepower[df.horsepower>200].value_counts().sum()
# Out:
# 5

# %%
df.horsepower[df.horsepower<90].value_counts().sum()
# Out:
# 88

# %%
df.horsepower[(df.horsepower>90) & (df.horsepower<200)].value_counts().sum()
# Out:
# 106

# %%
df.enginesize[df.enginesize>250].value_counts().sum()
# Out:
# 5

# %%
df.enginesize[df.enginesize<100].value_counts().sum()
# Out:
# 66

# %%
df.enginesize[(df.enginesize<250)&(df.enginesize>100)].value_counts().sum()
# Out:
# 134

# %% [markdown]
# # DATA VISUALIZATIONS

# %%
import seaborn as sns

# %%
sns.catplot(y="price",x="fueltype",data=df);

# %%
sns.catplot(y="price",x="aspiration",data=df);

# %%
sns.catplot(y="price",x="carbody",data=df);

# %%
sns.catplot(y="price",x="enginetype",data=df);

# %%
sns.catplot(y="price",x="fuelsystem",data=df);

# %%
sns.distplot(df.price);
# Out:
# C:\Users\fassf\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.horsepower);
# Out:
# C:\Users\fassf\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.barplot(x="carbody",y="horsepower",data=df);

# %%
sns.barplot(x="carbody",y="price",data=df);

# %%
sns.barplot(x="fueltype",y="enginesize",data=df);

# %%
sns.barplot(x="cylindernumber",y="horsepower",data=df);

# %%
sns.barplot(x="cylindernumber",y="price",data=df);

# %%
sns.scatterplot(x="price",y="horsepower",hue="fueltype",data=df);

# %%
sns.scatterplot(x="price",y="horsepower",hue="carbody",data=df);

# %%
sns.scatterplot(x="price",y="horsepower",hue="drivewheel",data=df);

# %%
sns.scatterplot(x="price",y="enginesize",hue="carbody",data=df);

# %%
sns.scatterplot(x="price",y="enginesize",hue="fueltype",data=df);

# %%
sns.scatterplot(x="price",y="enginesize",hue="aspiration",data=df);

# %%
corr=df.drop(["car_ID","symboling"],1)
corr=corr.corr()
sns.heatmap(corr,annot=True,linewidth=0.4)
# Out:
# <AxesSubplot:>

# %%
import missingno as mn

# %%
mn.matrix(df);

# %%
from scipy.stats import shapiro,spearmanr,pearsonr

# %%
df["price"].corr(df.horsepower)
# Out:
# 0.8081388225362212

# %%
shapiro(df.price)
# Out:
# ShapiroResult(statistic=0.8006654381752014, pvalue=1.8491777441833604e-15)

# %%
shapiro(df.horsepower)
# Out:
# ShapiroResult(statistic=0.8836248517036438, pvalue=1.7366445087541038e-11)

# %%
spearmanr(df["price"],df["horsepower"])
# Out:
# SpearmanrResult(correlation=0.8546096111609129, pvalue=1.0967646925749196e-59)

# %%
df["price"].corr(df.enginesize)
# Out:
# 0.8741448025245112

# %%
shapiro(df.price)
# Out:
# ShapiroResult(statistic=0.8006654381752014, pvalue=1.8491777441833604e-15)

# %%
shapiro(df.enginesize)
# Out:
# ShapiroResult(statistic=0.8294388651847839, pvalue=3.0569154792128156e-14)

# %%
spearmanr(df["price"],df["enginesize"])
# Out:
# SpearmanrResult(correlation=0.825996248788791, pvalue=1.9437256267294588e-52)

# %%
df["price"].corr(df.curbweight)
# Out:
# 0.8353048793372965

# %%
shapiro(df.price)
# Out:
# ShapiroResult(statistic=0.8006654381752014, pvalue=1.8491777441833604e-15)

# %%
shapiro(df.curbweight)
# Out:
# ShapiroResult(statistic=0.9530424475669861, pvalue=2.8916113024024526e-06)

# %%
spearmanr(df["price"],df["curbweight"])
# Out:
# SpearmanrResult(correlation=0.9090666905857352, pvalue=4.0026112686216925e-79)

# %%
df["price"].corr(df.highwaympg)
# Out:
# -0.6975990916465566

# %%
shapiro(df.price)
# Out:
# ShapiroResult(statistic=0.8006654381752014, pvalue=1.8491777441833604e-15)

# %%
shapiro(df.highwaympg)
# Out:
# ShapiroResult(statistic=0.9735103845596313, pvalue=0.0006515368004329503)

# %%
spearmanr(df["price"],df["highwaympg"])
# Out:
# SpearmanrResult(correlation=-0.8227291026518385, pvalue=1.0749573921925922e-51)
